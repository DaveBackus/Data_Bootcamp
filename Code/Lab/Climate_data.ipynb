# %% [markdown]
# # Climate data
#
# There's a lot of climate data available online.  This notebook follows Radford Neal's [blog post](https://radfordneal.wordpress.com/2015/12/03/what-can-global-temperature-data-tell-us/) and his links to climate data from NASA.  See also his links to [followup](https://radfordneal.wordpress.com/2015/12/19/has-there-been-a-pause-in-global-warming/) [posts](https://radfordneal.wordpress.com/2016/01/10/critique-of-debunking-the-climate-hiatus-by-rajaratnam-romano-tsiang-and-diffenbaugh/) and R code. This is not an area in which I have even a little expertise, so I make no claims any of this makes any sense.
#
# Data links
#
# * http://data.giss.nasa.gov/gistemp/
#
# This notebook written by Dave Backus for the NYU Stern course [Data Bootcamp](http://databootcamp.nyuecon.com/).
#
# **Warning:**  This doesn't work yet.

# %%
import pandas as pd
import numpy as np

# %%
url = 'http://data.giss.nasa.gov/gistemp/tabledata_v3/GLB.Ts+dSST.txt'
giss = pd.read_csv(url, na_values=['***', '****'], sep=' +', skiprows=7, engine='python')
giss
# Out:
#          Year       Jan      Feb       Mar        Apr          May     Jun  \
# 0        1880       -29      -20       -18        -27          -14     -28
# 1        1881        -9      -13         2         -2           -4     -28
# 2        1882        10        9         2        -19          -17     -24
# 3        1883       -33      -41       -17        -24          -25     -11
# 4        1884       -18      -11       -33        -35          -31     -37
# 5        1885       -64      -29       -23        -43          -41     -50
# 6        1886       -41      -45       -41        -29          -27     -38
# 7        1887       -65      -48       -31        -37          -33     -20
# 8        1888       -43      -42       -47        -28          -22     -20
# 9        1889       -19       15         5          5           -2     -11
# 10       1890       -46      -46       -40        -37          -47     -27
# ...

# %%
giss.shape
# Out:
# (10, 1)

# %%
lis(giss)
